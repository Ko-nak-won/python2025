# %% [markdown]
# 1~20번: NumPy (객관식 + 단답식 혼합)
#
# Q1. 다음 중 NumPy 배열을 생성하는 올바른 방법은? = C
#
# A. np.arr([1,2,3])
#
# B. numpy.array(1,2,3)
#
# C. np.array([1,2,3])
#
# D. np.make_array([1,2,3])
#
# Q2. np.zeros((2, 2))의 결과는? = [0, 0], [0, 0] 2행 2열
#
# Q3. 브로드캐스팅(broadcasting)의 조건으로 올바른 것은? = 뒷차원이 같아야함함
#
# Q4. a = np.array([[1,2],[3,4]]), a.shape는? = integer64 , 2차원원
#
# Q5. np.arange(1, 10, 2)의 결과는? = 1 3 5 7 9
#
# Q6. np.eye(3)는 어떤 배열을 생성하는가? 3행 3열의 대각선이 0으로된 정사각행렬 생성성
#
# Q7. np.sum(np.array([[1,2],[3,4]]), axis=1)의 결과는?
#
# Q8. a = np.array([1,2,3]), a * 2의 결과는? = [3, 6, 9]
#
# Q9. np.array([1,2,3]) @ np.array([4,5,6])의 결과는? = [5, 7, 9]
#
# Q10. np.linspace(0, 1, 3)의 결과는? = 0, 0.5, 1
#
# Q11. a = np.array([1,2,3]), a.reshape((3,1)).shape는?
#
# Q12. NumPy에서 난수를 생성하는 함수는? = B
#
# A. np.seed()
#
# B. np.random.rand()
#
# C. np.generate()
#
# D. np.create.rand()
#
# Q13. a = np.array([[1,2],[3,4]]), a.T는?
#
# Q14. np.max(np.array([1, 2, 3]))의 결과는?
#
# Q15. np.mean(np.array([1, 2, 3, 4]))의 결과는?
#
# Q16. np.array([True, False]) & np.array([True, True])의 결과는?
#
# Q17. a = np.array([1,2,3]), np.where(a > 1)의 반환값은?
#
# Q18. np.all(np.array([True, True, False]))의 결과는?
#
# Q19. np.any(np.array([False, False, True]))의 결과는?
#
# Q20. 배열 슬라이싱에서 a[1:]은 어떤 의미인가?
#
# ✅ 21~40번: Pandas (객관식 + 단답식 혼합)
#
# Q21. 다음 중 Series를 생성하는 방법으로 옳은 것은? = A
#
# A. pd.Series([1,2,3])
#
# B. pd.series([1,2,3])
#
# C. pd.Array([1,2,3])
#
# D. Series([1,2,3])
#
# Q22. df = pd.DataFrame(...), df.shape는 무엇을 반환하는가? =
#
# Q23. df.head(2)는 어떤 결과를 출력하는가?
#
# Q24. df['col']은 어떤 형태의 객체를 반환하는가?
#
# Q25. df.loc[0]과 df.iloc[0]의 차이는?
#
# Q26. df.fillna(0)의 역할은?
#
# Q27. df.dropna()는 어떤 행을 삭제하는가?
#
# Q28. df[df['age'] > 25]의 의미는?
#
# Q29. df.groupby('gender').mean()의 의미는?
#
# Q30. df.sort_values(by='score', ascending=False)의 결과는?
#
# Q31. df.describe()가 제공하는 정보는?
#
# Q32. df['col'].value_counts()는 어떤 결과를 보여주는가?
#
# Q33. df['date'] = pd.to_datetime(df['date'])의 목적은?
#
# Q34. df.set_index('id')의 역할은?
#
# Q35. df.reset_index()의 역할은?
#
# Q36. df.columns는 어떤 정보를 제공하는가?
#
# Q37. df.isnull().sum()은 어떤 값을 반환하는가?
#
# Q38. Pandas에서 열(column) 삭제 방법은?
#
# A. df.drop('col')
#
# B. df.remove('col')
#
# C. df.drop(columns='col')
#
# D. df.del('col')
#
# Q39. df['col'].apply(lambda x: x*2)의 결과는?
#
# Q40. Pandas에서 CSV 파일 저장 방법은?
#
# A. df.save('file.csv')
#
# B. df.to_csv('file.csv')
#
# C. df.export('file.csv')
#
# D. df.csv_save('file.csv')
